# %% [markdown]
# ## 5.4 일별 시세 조회 API
# DBUpdater class\
# 우선 MarketDB class를 만들어 어떻게 동작하는지 보고, Analyzer.py를 만들자.\
# ### 5.4.1 class 구조
# ### 5.4.2 생성자와 소멸자로 DB 연결관리
# 생성자 __init__\
# 소멸자 __del__
# ### 5.4.3 일별시세 조회 API
# ### 5.4.4 기본 인수값 처리
# 조회 시작일과 조회 종료일을 인수로 넘겨주지 않았을 때 기본 인수값으로 처리하는 함수 작성
# ### 5.4.5 정규표현식으로 연-월-일 분리하기

# %%
import re
start_date = "2020 year 8/30"
start_lst = re.split(r'\D+',start_date)
start_year = int(start_lst[0])
start_month = int(start_lst[1])
start_day = int(start_lst[2])
start_date=f"{start_year:04d}-{start_month:02d}-{start_day:02d}"
print("start_date: ", start_date)
# Out:
# start_date:  2020-08-30

# %% [markdown]
# ### 5.4.6 회사명으로 종목코드 조회하기
# ### 5.4.7 Analyzer.py 전체소스코드
# C:\myPackage\Investar\test.py
#
# naverDatabase_sec.py\
# import matplotlib.pyplot as plt\
# from Analyzer import MarketDB  # ①
#
# #mk = Analyzer.MarketDB()  # ② \
# mk = MarketDB() \
# df = mk.get_daily_price('005930', '2023-07-10', '2025-06-30')  # ③
#
# plt.figure(figsize=(9, 6))\
# plt.subplot(2, 1, 1)\\
# plt.title('Samsung Electronics (Investar Data)')\
# plt.plot(df.index, df['close'], 'c', label='Close')  # ④ \
# plt.legend(loc='best')\
# plt.subplot(2, 1, 2)\
# plt.bar(df.index, df['volume'], color='g', label='Volume')\
# plt.legend(loc='best')\
# plt.show()

# %% [markdown]
# ![image.png](attachment:099af29c-f930-43c9-a6ff-91ed448b3d87.png)
